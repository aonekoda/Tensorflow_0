# %% [markdown]
# # Inference and Validation
#
# 훈련된 모형을 사용하여 prediction을 수행할 수 있다. 이것을 **inference**라고 부른다. 이 과정에서 훈련 데이터에 대해 과대적합이 일어날 수 있는데 이것을 **overfitting**이라고 한다. overfitting를 확인하기 위해서 훈련데이터를 **validation** set으로 나눈다.  overfitting 문제를 해결하기 위해서 regularization(규제화) 또는 dropout을 수행한다.  훈련을 진행하는 과정에서 validation performance 를 모니터링하여 overfitting이 발생하는지 확인할 수 있다.

# %% [markdown]
# ## Import Resources

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
print('Using:')
print('TensorFlow version:', tf.__version__)
print('tf.keras version:', tf.keras.__version__)
print('Running on GPU' if tf.test.is_gpu_available() else 'GPU device not found. Running on CPU')
# Out:
# Using:
# TensorFlow version: 2.3.0
# tf.keras version: 2.4.0
# GPU device not found. Running on CPU

# %% [markdown]
# ## Load the Dataset
#
# Fashion-MNIST dataset을 load 한다. 이번 예제에서는 전체 데이터를 train dataset, validation dataset, test dataset으로 나눈다.
#
# `train`은 60,000 examples을 포함하고 `test` 는 10,000 examples을 포함하고 있다.
#
# train dataset에서 일부 10,000 건의 example을 별도의 validation dataset으로 지정한다.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# %% [markdown]
# ## 데이터 탐색
#
# 모델을 훈련하기 전에 데이터셋 구조를 살펴보자. 다음 코드는 훈련 세트에 60,000개의 이미지가 있다는 것을 보여준다. 각 이미지는 28x28 픽셀로 표현된다:

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# 비슷하게 훈련 세트에는 60,000개의 레이블이 있다:

# %%
len(y_train)
# Out:
# 60000

# %% [markdown]
# 각 레이블은 0과 9사이의 정수이다:

# %%
y_train
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %% [markdown]
# 테스트 세트에는 10,000개의 이미지가 있다. 이 이미지도 28x28 픽셀로 표현된다:

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# 테스트 세트는 10,000개의 이미지에 대한 레이블을 가지고 있다:

# %%
len(y_train)
# Out:
# 60000

# %% [markdown]
# ### 데이터 전처리

# %%
# Preprocess the data (these are NumPy arrays)
x_train = x_train.reshape(60000, 784).astype("float32") / 255
x_test = x_test.reshape(10000, 784).astype("float32") / 255

y_train = y_train.astype("float32")
y_test = y_test.astype("float32")

# %% [markdown]
# ###  validation dataset

# %%
# Reserve 15,000 samples for validation
x_val = x_train[-15000:]
y_val = y_train[-15000:]
x_train = x_train[:-15000]
y_train = y_train[:-15000]

# %%
num_training_examples = len(x_train)
num_validation_examples = len(x_val)
num_test_examples = len(x_test)

print('There are {:,} images in the training set'.format(num_training_examples))
print('There are {:,} images in the validation set'.format(num_validation_examples))
print('There are {:,} images in the test set'.format(num_test_examples))
# Out:
# There are 45,000 images in the training set
# There are 15,000 images in the validation set
# There are 10,000 images in the test set

# %%
# fashion MNIST dataset class name
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal',      'Shirt',   'Sneaker',  'Bag',   'Ankle boot']

# %% [markdown]
# ## Create Pipeline

# %%
x_train = x_train.reshape(num_training_examples, 28, 28,1)
x_val = x_val.reshape(num_validation_examples, 28, 28,1)
x_test = x_test.reshape(num_test_examples, 28, 28,1)

training_set = tf.data.Dataset.from_tensor_slices((x_train, y_train))
validation_set = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_set = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %%
def normalize(image, label):
    image = tf.cast(image, tf.float32)
    image /= 255
    return image, label

batch_size = 64

training_batches = training_set.cache().shuffle(num_training_examples//4).batch(batch_size).map(normalize).prefetch(1)
validation_batches = validation_set.cache().batch(batch_size).map(normalize).prefetch(1)
testing_batches = test_set.cache().batch(batch_size).map(normalize).prefetch(1)

# %% [markdown]
# ## Build the Model

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28,1)),
        tf.keras.layers.Dense(512, activation = 'relu'),
        tf.keras.layers.Dense(256, activation = 'relu'),
        tf.keras.layers.Dense(128, activation = 'relu'),
        tf.keras.layers.Dense(64, activation = 'relu'),
        tf.keras.layers.Dense(10, activation = 'softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Evaluate Loss and Accuracy on the Test Set
#
# Evaluation은 모형을 훈련하면서 training set에 속하지 않은 데이터(validation dataset)를 사용하여 모형의 performance를 확인하는 것이다.

# %%
loss, accuracy = model.evaluate(testing_batches)

print('\nLoss on the TEST Set: {:,.3f}'.format(loss))
print('Accuracy on the TEST Set: {:.3%}'.format(accuracy))
# Out:
# 157/157 [==============================] - 0s 2ms/step - loss: 2.3026 - accuracy: 0.1135
#
# Loss on the TEST Set: 2.303
# Accuracy on the TEST Set: 11.350%

# %% [markdown]
# 모형이 훈련되지 않았으므로 accuracy는 대략 10% 내외가 된다.

# %% [markdown]
# ## Train the Model with the Validation Set
#
# 앞서 예제와 같은 방법으로 모형을 훈련할 수 있다.
#
# 매 training epoch 마다 training set과 validation set에 대한 loss를 계산한다. 이를 통해 모형의 학습 과정을 모니터링 할 수 있다. validation set은 모형의 훈련에 사용되지 않는다. 대신 모형이 overfitting 되지 않는지를 확인할 수 있다.
#
# `.fit` method 에서 `validation_data=validation_batches` argument에서 validation set을 지정하여 수행한다.

# %%
EPOCHS = 40

history = model.fit(training_batches,
                    epochs = EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.9596 - accuracy: 0.6262 - val_loss: 1.0781 - val_accuracy: 0.5965
# Epoch 2/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.6313 - accuracy: 0.7643 - val_loss: 0.5261 - val_accuracy: 0.8031
# Epoch 3/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5117 - accuracy: 0.8128 - val_loss: 0.5427 - val_accuracy: 0.8011
# Epoch 4/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4500 - accuracy: 0.8342 - val_loss: 0.6387 - val_accuracy: 0.7679
# Epoch 5/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4128 - accuracy: 0.8468 - val_loss: 0.4726 - val_accuracy: 0.8276
# Epoch 6/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3892 - accuracy: 0.8567 - val_loss: 0.4076 - val_accuracy: 0.8529
# Epoch 7/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3703 - accuracy: 0.8639 - val_loss: 0.4982 - val_accuracy: 0.8062
# Epoch 8/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3539 - accuracy: 0.8695 - val_loss: 0.4361 - val_accuracy: 0.8465
# Epoch 9/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3422 - accuracy: 0.8743 - val_loss: 0.5471 - val_accuracy: 0.8137
# Epoch 10/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3325 - accuracy: 0.8779 - val_loss: 0.3743 - val_accuracy: 0.8639
# Epoch 11/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3214 - accuracy: 0.8821 - val_loss: 0.3921 - val_accuracy: 0.8589
# Epoch 12/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3127 - accuracy: 0.8843 - val_loss: 0.3750 - val_accuracy: 0.8650
# Epoch 13/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3045 - accuracy: 0.8876 - val_loss: 0.3673 - val_accuracy: 0.8691
# Epoch 14/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2999 - accuracy: 0.8887 - val_loss: 0.4199 - val_accuracy: 0.8553
# Epoch 15/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2916 - accuracy: 0.8920 - val_loss: 0.3533 - val_accuracy: 0.8751
# Epoch 16/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2863 - accuracy: 0.8942 - val_loss: 0.4846 - val_accuracy: 0.8248
# Epoch 17/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2789 - accuracy: 0.8979 - val_loss: 0.3545 - val_accuracy: 0.8809
# Epoch 18/40
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2732 - accuracy: 0.8982 - val_loss: 0.3656 - val_accuracy: 0.8865
# Epoch 19/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2709 - accuracy: 0.9003 - val_loss: 0.3621 - val_accuracy: 0.8721
# Epoch 20/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2653 - accuracy: 0.9017 - val_loss: 0.3507 - val_accuracy: 0.8862
# Epoch 21/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2626 - accuracy: 0.9030 - val_loss: 0.3647 - val_accuracy: 0.8677
# Epoch 22/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2585 - accuracy: 0.9042 - val_loss: 0.3979 - val_accuracy: 0.8765
# Epoch 23/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2563 - accuracy: 0.9075 - val_loss: 0.3588 - val_accuracy: 0.8810
# Epoch 24/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2553 - accuracy: 0.9061 - val_loss: 0.3581 - val_accuracy: 0.8836
# Epoch 25/40
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2514 - accuracy: 0.9088 - val_loss: 0.3538 - val_accuracy: 0.8885
# Epoch 26/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2500 - accuracy: 0.9094 - val_loss: 0.5021 - val_accuracy: 0.8203
# Epoch 27/40
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2458 - accuracy: 0.9098 - val_loss: 0.3832 - val_accuracy: 0.8772
# Epoch 28/40
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2455 - accuracy: 0.9111 - val_loss: 0.4843 - val_accuracy: 0.8543
# Epoch 29/40
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2467 - accuracy: 0.9082 - val_loss: 0.5976 - val_accuracy: 0.8509
# Epoch 30/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2427 - accuracy: 0.9108 - val_loss: 0.5039 - val_accuracy: 0.8739
# Epoch 31/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2405 - accuracy: 0.9129 - val_loss: 0.6901 - val_accuracy: 0.8331
# Epoch 32/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2421 - accuracy: 0.9108 - val_loss: 0.6227 - val_accuracy: 0.8354
# Epoch 33/40
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2343 - accuracy: 0.9143 - val_loss: 0.6201 - val_accuracy: 0.8467
# Epoch 34/40
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2361 - accuracy: 0.9121 - val_loss: 0.4181 - val_accuracy: 0.8827
# Epoch 35/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2384 - accuracy: 0.9128 - val_loss: 0.4369 - val_accuracy: 0.8640
# Epoch 36/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2324 - accuracy: 0.9138 - val_loss: 0.4061 - val_accuracy: 0.8898
# Epoch 37/40
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2336 - accuracy: 0.9155 - val_loss: 0.4888 - val_accuracy: 0.8699
# Epoch 38/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2329 - accuracy: 0.9158 - val_loss: 0.4998 - val_accuracy: 0.8737
# Epoch 39/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2314 - accuracy: 0.9167 - val_loss: 0.4903 - val_accuracy: 0.8710
# Epoch 40/40
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2296 - accuracy: 0.9172 - val_loss: 0.4386 - val_accuracy: 0.8848

# %% [markdown]
# ## Loss and Validation Plots
#
# 위에서 40 epoch 으로 모형을 훈련하였다. 훈련 결과를 시각화하여 표현해 보자.
#
# 해당 결과를 확인해 보면 validation set에 대한 loss보다 training dataset에 대한 loss는 매우 작은 것을 볼 수 있는데 이를 통해 해당 모형이 overfitting 되었다고 판단할 수 있다.
#
# 모형이 훈련될 때 training set 과 the validation set 모두에 대해 loss 와 accuracy 를 확인한다. `.fit` method는 `history` object를 리턴한다. `history.history` 속성은 **dictionary**로  training accuracy 와 loss 를 각 epochs 마다 기록한다.

# %%
# Check that history.history is a dictionary
print('history.history has type:', type(history.history))

# Print the keys of the history.history dictionary
print('\nThe keys of history.history are:', list(history.history.keys()))
# Out:
# history.history has type: <class 'dict'>
#
# The keys of history.history are: ['loss', 'accuracy', 'val_loss', 'val_accuracy']

# %% [markdown]
# `history.history` dictionary 를 plot으로 시각화 하면 해당 모형이 훈련되는 과정에서 loss와 accuracy를 확인할 수 있다.

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Early Stopping
#
# overfitting 문제를 해결하는 방법 중 하나가 Early Stopping이다.
# overfitting이 되면 모형이 일반화(generalize)에 실패하여 train set에 대해서는 과대 적합되고 validation set에는 오히려 정확도가 떨어지게 된다.
#
# 시각화 결과를 살펴보면 훈련 시작시 validation loss가 감소하기 시작하고 몇 epoch 이후에는 평준화되고 이후 증가하기 시작한다는 것을 알 수 있다.
#
# 이때 overfitting이 발생하기 전에 훈련을 조기 종료하는 방법이 Early Stopping이다.
#
# **early-stopping**을 하기 위해서 `tf.keras`에서는 **callback**을 사용한다. `.fit()` method 에서 `callbacks` keyword argument를 사용한다.
#
# ```python
# tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
# ```
#
# * `monitor` argument : training을 종료하기 위해서 모니터링할 성능 지표를 지정한다.
# * `patience` argument : 정해진 epoch 수 모니터링 지표가 상당한 개선이 이루어지지 않으면 훈련을 중단한다.
# * `min_delta` argument :  개선된 것으로 판단할 수 있는 최소값을 지정한다.
#
# 참고) [EarlyStopping
# documentation](https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/keras/callbacks/EarlyStopping#class_earlystopping).

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28,1)),
        tf.keras.layers.Dense(512, activation = 'relu'),
        tf.keras.layers.Dense(256, activation = 'relu'),
        tf.keras.layers.Dense(128, activation = 'relu'),
        tf.keras.layers.Dense(64, activation = 'relu'),
        tf.keras.layers.Dense(10, activation = 'softmax')
])


model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Stop training when there is no improvement in the validation loss for 5 consecutive epochs
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(training_batches,
                    epochs = 100,
                    validation_data=validation_batches,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.9347 - accuracy: 0.6412 - val_loss: 1.1752 - val_accuracy: 0.5230
# Epoch 2/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.6206 - accuracy: 0.7677 - val_loss: 0.5885 - val_accuracy: 0.7789
# Epoch 3/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.5083 - accuracy: 0.8128 - val_loss: 0.5551 - val_accuracy: 0.7919
# Epoch 4/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.4519 - accuracy: 0.8351 - val_loss: 0.5111 - val_accuracy: 0.8127
# Epoch 5/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.4151 - accuracy: 0.8482 - val_loss: 0.4303 - val_accuracy: 0.8410
# Epoch 6/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3887 - accuracy: 0.8577 - val_loss: 0.4801 - val_accuracy: 0.8277
# Epoch 7/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.3715 - accuracy: 0.8639 - val_loss: 0.5380 - val_accuracy: 0.8003
# Epoch 8/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.3558 - accuracy: 0.8697 - val_loss: 0.4431 - val_accuracy: 0.8399
# Epoch 9/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.3443 - accuracy: 0.8735 - val_loss: 0.4773 - val_accuracy: 0.8334
# Epoch 10/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.3332 - accuracy: 0.8776 - val_loss: 0.3736 - val_accuracy: 0.8675
# Epoch 11/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.3245 - accuracy: 0.8805 - val_loss: 0.3506 - val_accuracy: 0.8730
# Epoch 12/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.3157 - accuracy: 0.8853 - val_loss: 0.4378 - val_accuracy: 0.8393
# Epoch 13/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.3062 - accuracy: 0.8877 - val_loss: 0.4308 - val_accuracy: 0.8490
# Epoch 14/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2994 - accuracy: 0.8900 - val_loss: 0.3742 - val_accuracy: 0.8683
# Epoch 15/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2930 - accuracy: 0.8916 - val_loss: 0.3346 - val_accuracy: 0.8801
# Epoch 16/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2880 - accuracy: 0.8927 - val_loss: 0.4439 - val_accuracy: 0.8401
# Epoch 17/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2813 - accuracy: 0.8946 - val_loss: 0.4436 - val_accuracy: 0.8535
# Epoch 18/100
# 704/704 [==============================] - 6s 9ms/step - loss: 0.2757 - accuracy: 0.8986 - val_loss: 0.4633 - val_accuracy: 0.8471
# Epoch 19/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2705 - accuracy: 0.9008 - val_loss: 0.3281 - val_accuracy: 0.8878
# Epoch 20/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2676 - accuracy: 0.9018 - val_loss: 0.3444 - val_accuracy: 0.8806
# Epoch 21/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2613 - accuracy: 0.9039 - val_loss: 0.4192 - val_accuracy: 0.8563
# Epoch 22/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2595 - accuracy: 0.9043 - val_loss: 0.3634 - val_accuracy: 0.8688
# Epoch 23/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2564 - accuracy: 0.9044 - val_loss: 0.4359 - val_accuracy: 0.8505
# Epoch 24/100
# 704/704 [==============================] - 6s 8ms/step - loss: 0.2523 - accuracy: 0.9074 - val_loss: 0.4133 - val_accuracy: 0.8567

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(len(training_accuracy))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Dropout
#
# overfitting 을 해결할 수 있는 또다른 방법으로는  **dropout**이 있다. dropout 은 모형의 훈련과정에서 random하게 network의 일부 neurons을 삭제하는 것이다.  `tf.keras`에서는 `tf.keras.layers.Dropout()` layers 를 활용한다.
#
# ```python
# tf.keras.layers.Dropout(rate)
# ```
#
# * rate : 훈련 중 임의로 삭제할 neuron의 비율을 지정한다. (0~1사이의 값)
#
# input layer에 대해서는 dropout을 지정하지 않는다. 또한 훈련과정에서만 dropout 이 적용되고 훈련이 끝난 모형을 prediction에 사용할때는 dropout이 적용되지 않는다.

# %% [markdown]
# > **Exercise:** 이전에 생성한 모형에 3개의 dropout layers를 추가한다. 이때 `rate=0.2`로 지정하시오. 그리고 해당 모형을 다시 훈련시키고 overfitting 이 해결되는지 확인해 보시오.

# %%
## Solution
my_model = tf.keras.Sequential([
           tf.keras.layers.Flatten(input_shape=(28,28,1)),
           tf.keras.layers.Dense(256, activation = 'relu'),
           tf.keras.layers.Dropout(0.2),
           tf.keras.layers.Dense(128, activation = 'relu'),
           tf.keras.layers.Dropout(0.2),
           tf.keras.layers.Dense(64, activation = 'relu'),
           tf.keras.layers.Dropout(0.2),
           tf.keras.layers.Dense(10, activation = 'softmax')
])

my_model.compile(optimizer='adam',
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])

EPOCHS = 30

history = my_model.fit(training_batches,
                       epochs=EPOCHS,
                       validation_data=validation_batches)
# Out:
# Epoch 1/30
# 704/704 [==============================] - 3s 4ms/step - loss: 1.0745 - accuracy: 0.5870 - val_loss: 0.7190 - val_accuracy: 0.7367
# Epoch 2/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.6787 - accuracy: 0.7465 - val_loss: 0.6140 - val_accuracy: 0.7777
# Epoch 3/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.5736 - accuracy: 0.7903 - val_loss: 0.5213 - val_accuracy: 0.8083
# Epoch 4/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.5163 - accuracy: 0.8158 - val_loss: 0.5237 - val_accuracy: 0.8107
# Epoch 5/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.4778 - accuracy: 0.8314 - val_loss: 0.4558 - val_accuracy: 0.8335
# Epoch 6/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.4510 - accuracy: 0.8412 - val_loss: 0.4585 - val_accuracy: 0.8301
# Epoch 7/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.4307 - accuracy: 0.8464 - val_loss: 0.4177 - val_accuracy: 0.8492
# Epoch 8/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.4163 - accuracy: 0.8530 - val_loss: 0.4278 - val_accuracy: 0.8441
# Epoch 9/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.4043 - accuracy: 0.8583 - val_loss: 0.3917 - val_accuracy: 0.8578
# Epoch 10/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3911 - accuracy: 0.8621 - val_loss: 0.3953 - val_accuracy: 0.8601
# Epoch 11/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3818 - accuracy: 0.8650 - val_loss: 0.3872 - val_accuracy: 0.8611
# Epoch 12/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3753 - accuracy: 0.8671 - val_loss: 0.3746 - val_accuracy: 0.8702
# Epoch 13/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3685 - accuracy: 0.8703 - val_loss: 0.3714 - val_accuracy: 0.8715
# Epoch 14/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3604 - accuracy: 0.8721 - val_loss: 0.3750 - val_accuracy: 0.8703
# Epoch 15/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3562 - accuracy: 0.8743 - val_loss: 0.3826 - val_accuracy: 0.8650
# Epoch 16/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3519 - accuracy: 0.8754 - val_loss: 0.3708 - val_accuracy: 0.8718
# Epoch 17/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3476 - accuracy: 0.8780 - val_loss: 0.3731 - val_accuracy: 0.8699
# Epoch 18/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3435 - accuracy: 0.8782 - val_loss: 0.3603 - val_accuracy: 0.8757
# Epoch 19/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3389 - accuracy: 0.8799 - val_loss: 0.3645 - val_accuracy: 0.8737
# Epoch 20/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3382 - accuracy: 0.8824 - val_loss: 0.3675 - val_accuracy: 0.8718
# Epoch 21/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3334 - accuracy: 0.8815 - val_loss: 0.4050 - val_accuracy: 0.8617
# Epoch 22/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3283 - accuracy: 0.8839 - val_loss: 0.3746 - val_accuracy: 0.8684
# Epoch 23/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3263 - accuracy: 0.8845 - val_loss: 0.3601 - val_accuracy: 0.8761
# Epoch 24/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3239 - accuracy: 0.8858 - val_loss: 0.3690 - val_accuracy: 0.8775
# Epoch 25/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3188 - accuracy: 0.8881 - val_loss: 0.3624 - val_accuracy: 0.8759
# Epoch 26/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3164 - accuracy: 0.8904 - val_loss: 0.3533 - val_accuracy: 0.8803
# Epoch 27/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3165 - accuracy: 0.8896 - val_loss: 0.3616 - val_accuracy: 0.8767
# Epoch 28/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3156 - accuracy: 0.8888 - val_loss: 0.4768 - val_accuracy: 0.8539
# Epoch 29/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3169 - accuracy: 0.8890 - val_loss: 0.3445 - val_accuracy: 0.8829
# Epoch 30/30
# 704/704 [==============================] - 3s 4ms/step - loss: 0.3103 - accuracy: 0.8919 - val_loss: 0.3596 - val_accuracy: 0.8791

# %% [markdown]
# ## Inference
#
# 훈련된 모형을 사용하여 prediction을 수행하고 해당 결과를 시각화 하며 표현해 본다.

# %%
for image_batch, label_batch in testing_batches.take(1):
    ps = model.predict(image_batch)
    images = image_batch.numpy().squeeze()
    labels = label_batch.numpy()


plt.figure(figsize=(10,15))

for n in range(30):
    plt.subplot(6,5,n+1)
    plt.imshow(images[n], cmap = plt.cm.binary)
    color = 'green' if np.argmax(ps[n]) == labels[n] else 'red'
    plt.title(class_names[np.argmax(ps[n])], color=color)
    plt.axis('off')
