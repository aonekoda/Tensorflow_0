# %% [markdown]
# # Inference and Validation
#
# 훈련된 모형을 사용하여 prediction을 수행할 수 있다. 이것을 **inference**라고 부른다. 이 과정에서 훈련 데이터에 대해 과대적합이 일어날 수 있는데 이것을 **overfitting**이라고 한다. overfitting를 확인하기 위해서 훈련데이터를 **validation** set으로 나눈다.  overfitting 문제를 해결하기 위해서 regularization(규제화) 또는 dropout을 수행한다.  훈련을 진행하는 과정에서 validation performance 를 모니터링하여 overfitting이 발생하는지 확인할 수 있다.

# %% [markdown]
# ## Import Resources

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
print('Using:')
print('TensorFlow version:', tf.__version__)
print('tf.keras version:', tf.keras.__version__)
print('Running on GPU' if tf.test.is_gpu_available() else 'GPU device not found. Running on CPU')
# Out:
# Using:
# TensorFlow version: 2.3.1
# tf.keras version: 2.4.0
# GPU device not found. Running on CPU

# %% [markdown]
# ## Load the Dataset
#
# Fashion-MNIST dataset을 load 한다. 이번 예제에서는 전체 데이터를 train dataset, validation dataset, test dataset으로 나눈다.
#
# `train`은 60,000 examples을 포함하고 `test` 는 10,000 examples을 포함하고 있다.
#
# train dataset에서 일부 10,000 건의 example을 별도의 validation dataset으로 지정한다.

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# ## 데이터 탐색
#
# 모델을 훈련하기 전에 데이터셋 구조를 살펴보자. 다음 코드는 훈련 세트에 60,000개의 이미지가 있다는 것을 보여준다. 각 이미지는 28x28 픽셀로 표현된다:

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# 비슷하게 훈련 세트에는 60,000개의 레이블이 있다:

# %%
len(y_train)
# Out:
# 60000

# %% [markdown]
# 각 레이블은 0과 9사이의 정수이다:

# %%
y_train
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %% [markdown]
# 테스트 세트에는 10,000개의 이미지가 있다. 이 이미지도 28x28 픽셀로 표현된다:

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# 테스트 세트는 10,000개의 이미지에 대한 레이블을 가지고 있다:

# %%
len(y_train)
# Out:
# 60000

# %% [markdown]
# ### 데이터 전처리

# %%
# Preprocess the data (these are NumPy arrays)
x_train = x_train.reshape(60000, 784).astype("float32") / 255
x_test = x_test.reshape(10000, 784).astype("float32") / 255

y_train = y_train.astype("float32")
y_test = y_test.astype("float32")

# %% [markdown]
# ###  validation dataset

# %%
# Reserve 15,000 samples for validation
x_val = x_train[-15000:]
y_val = y_train[-15000:]
x_train = x_train[:-15000]
y_train = y_train[:-15000]

# %%
num_training_examples = len(x_train)
num_validation_examples = len(x_val)
num_test_examples = len(x_test)

print('There are {:,} images in the training set'.format(num_training_examples))
print('There are {:,} images in the validation set'.format(num_validation_examples))
print('There are {:,} images in the test set'.format(num_test_examples))
# Out:
# There are 45,000 images in the training set
# There are 15,000 images in the validation set
# There are 10,000 images in the test set

# %%
# fashion MNIST dataset class name
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal',      'Shirt',   'Sneaker',  'Bag',   'Ankle boot']

# %% [markdown]
# ## Create Pipeline

# %%
x_train = x_train.reshape(num_training_examples, 28, 28,1)
x_val = x_val.reshape(num_validation_examples, 28, 28,1)
x_test = x_test.reshape(num_test_examples, 28, 28,1)

training_set = tf.data.Dataset.from_tensor_slices((x_train, y_train))
validation_set = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_set = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %%
def normalize(image, label):
    image = tf.cast(image, tf.float32)
    image /= 255
    return image, label

batch_size = 64

training_batches = training_set.cache().shuffle(num_training_examples//4).batch(batch_size).map(normalize).prefetch(1)
validation_batches = validation_set.cache().batch(batch_size).map(normalize).prefetch(1)
testing_batches = test_set.cache().batch(batch_size).map(normalize).prefetch(1)

# %% [markdown]
# ## Build the Model

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28,1)),
        tf.keras.layers.Dense(512, activation = 'relu'),
        tf.keras.layers.Dense(256, activation = 'relu'),
        tf.keras.layers.Dense(128, activation = 'relu'),
        tf.keras.layers.Dense(64, activation = 'relu'),
        tf.keras.layers.Dense(10, activation = 'softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Evaluate Loss and Accuracy on the Test Set
#
# Evaluation은 모형을 훈련하면서 training set에 속하지 않은 데이터(validation dataset)를 사용하여 모형의 performance를 확인하는 것이다.

# %%
loss, accuracy = model.evaluate(testing_batches)

print('\nLoss on the TEST Set: {:,.3f}'.format(loss))
print('Accuracy on the TEST Set: {:.3%}'.format(accuracy))
# Out:
# 157/157 [==============================] - 0s 1ms/step - loss: 2.3025 - accuracy: 0.1005
#
# Loss on the TEST Set: 2.303
# Accuracy on the TEST Set: 10.050%

# %% [markdown]
# 모형이 훈련되지 않았으므로 accuracy는 대략 10% 내외가 된다.

# %% [markdown]
# ## Train the Model with the Validation Set
#
# 앞서 예제와 같은 방법으로 모형을 훈련할 수 있다.
#
# 매 training epoch 마다 training set과 validation set에 대한 loss를 계산한다. 이를 통해 모형의 학습 과정을 모니터링 할 수 있다. validation set은 모형의 훈련에 사용되지 않는다. 대신 모형이 overfitting 되지 않는지를 확인할 수 있다.
#
# `.fit` method 에서 `validation_data=validation_batches` argument에서 validation set을 지정하여 수행한다.

# %%
EPOCHS = 40

history = model.fit(training_batches,
                    epochs = EPOCHS,
                    validation_data=validation_batches)
# Out:
# Epoch 1/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.8842 - accuracy: 0.6630 - val_loss: 0.6078 - val_accuracy: 0.7747
# Epoch 2/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.5691 - accuracy: 0.7933 - val_loss: 0.5877 - val_accuracy: 0.7951
# Epoch 3/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.5091 - accuracy: 0.8151 - val_loss: 0.4707 - val_accuracy: 0.8253
# Epoch 4/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4600 - accuracy: 0.8323 - val_loss: 0.4399 - val_accuracy: 0.8384
# Epoch 5/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4254 - accuracy: 0.8446 - val_loss: 0.4531 - val_accuracy: 0.8341
# Epoch 6/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4009 - accuracy: 0.8538 - val_loss: 0.4458 - val_accuracy: 0.8385
# Epoch 7/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3809 - accuracy: 0.8610 - val_loss: 0.3981 - val_accuracy: 0.8531
# Epoch 8/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3629 - accuracy: 0.8679 - val_loss: 0.4024 - val_accuracy: 0.8573
# Epoch 9/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3508 - accuracy: 0.8718 - val_loss: 0.4671 - val_accuracy: 0.8239
# Epoch 10/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3437 - accuracy: 0.8734 - val_loss: 0.3791 - val_accuracy: 0.8596
# Epoch 11/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3300 - accuracy: 0.8787 - val_loss: 0.3488 - val_accuracy: 0.8762
# Epoch 12/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3204 - accuracy: 0.8815 - val_loss: 0.3544 - val_accuracy: 0.8714
# Epoch 13/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3122 - accuracy: 0.8851 - val_loss: 0.3467 - val_accuracy: 0.8747
# Epoch 14/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3042 - accuracy: 0.8885 - val_loss: 0.3432 - val_accuracy: 0.8772
# Epoch 15/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2973 - accuracy: 0.8901 - val_loss: 0.3469 - val_accuracy: 0.8744
# Epoch 16/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2949 - accuracy: 0.8896 - val_loss: 0.3529 - val_accuracy: 0.8747
# Epoch 17/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2813 - accuracy: 0.8952 - val_loss: 0.3323 - val_accuracy: 0.8818
# Epoch 18/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2783 - accuracy: 0.8965 - val_loss: 0.3387 - val_accuracy: 0.8766
# Epoch 19/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2738 - accuracy: 0.8976 - val_loss: 0.3487 - val_accuracy: 0.8779
# Epoch 20/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2669 - accuracy: 0.9010 - val_loss: 0.3322 - val_accuracy: 0.8824
# Epoch 21/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2592 - accuracy: 0.9046 - val_loss: 0.3616 - val_accuracy: 0.8757
# Epoch 22/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2541 - accuracy: 0.9078 - val_loss: 0.3443 - val_accuracy: 0.8786
# Epoch 23/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2475 - accuracy: 0.9079 - val_loss: 0.3315 - val_accuracy: 0.8837
# Epoch 24/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2449 - accuracy: 0.9084 - val_loss: 0.3242 - val_accuracy: 0.8874
# Epoch 25/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2405 - accuracy: 0.9098 - val_loss: 0.3096 - val_accuracy: 0.8879
# Epoch 26/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2320 - accuracy: 0.9141 - val_loss: 0.3155 - val_accuracy: 0.8903
# Epoch 27/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2284 - accuracy: 0.9152 - val_loss: 0.3465 - val_accuracy: 0.8819
# Epoch 28/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2236 - accuracy: 0.9162 - val_loss: 0.3257 - val_accuracy: 0.8881
# Epoch 29/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2216 - accuracy: 0.9172 - val_loss: 0.3475 - val_accuracy: 0.8847
# Epoch 30/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2162 - accuracy: 0.9195 - val_loss: 0.3190 - val_accuracy: 0.8914
# Epoch 31/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2110 - accuracy: 0.9213 - val_loss: 0.3227 - val_accuracy: 0.8905
# Epoch 32/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2065 - accuracy: 0.9235 - val_loss: 0.3252 - val_accuracy: 0.8869
# Epoch 33/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2056 - accuracy: 0.9228 - val_loss: 0.3206 - val_accuracy: 0.8895
# Epoch 34/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2020 - accuracy: 0.9234 - val_loss: 0.3333 - val_accuracy: 0.8872
# Epoch 35/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.1959 - accuracy: 0.9267 - val_loss: 0.3475 - val_accuracy: 0.8815
# Epoch 36/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.1926 - accuracy: 0.9281 - val_loss: 0.3381 - val_accuracy: 0.8903
# Epoch 37/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.1849 - accuracy: 0.9306 - val_loss: 0.3507 - val_accuracy: 0.8851
# Epoch 38/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.1879 - accuracy: 0.9297 - val_loss: 0.3881 - val_accuracy: 0.8777
# Epoch 39/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.1833 - accuracy: 0.9309 - val_loss: 0.3712 - val_accuracy: 0.8806
# Epoch 40/40
# 704/704 [==============================] - 2s 3ms/step - loss: 0.1767 - accuracy: 0.9335 - val_loss: 0.3434 - val_accuracy: 0.8884

# %% [markdown]
# ## Loss and Validation Plots
#
# 위에서 40 epoch 으로 모형을 훈련하였다. 훈련 결과를 시각화하여 표현해 보자.
#
# 해당 결과를 확인해 보면 validation set에 대한 loss보다 training dataset에 대한 loss는 매우 작은 것을 볼 수 있는데 이를 통해 해당 모형이 overfitting 되었다고 판단할 수 있다.
#
# 모형이 훈련될 때 training set 과 the validation set 모두에 대해 loss 와 accuracy 를 확인한다. `.fit` method는 `history` object를 리턴한다. `history.history` 속성은 **dictionary**로  training accuracy 와 loss 를 각 epochs 마다 기록한다.

# %%
# Check that history.history is a dictionary
print('history.history has type:', type(history.history))

# Print the keys of the history.history dictionary
print('\nThe keys of history.history are:', list(history.history.keys()))
# Out:
# history.history has type: <class 'dict'>
#
# The keys of history.history are: ['loss', 'accuracy', 'val_loss', 'val_accuracy']

# %% [markdown]
# `history.history` dictionary 를 plot으로 시각화 하면 해당 모형이 훈련되는 과정에서 loss와 accuracy를 확인할 수 있다.

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(EPOCHS)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Early Stopping
#
# overfitting 문제를 해결하는 방법 중 하나가 Early Stopping이다.
# overfitting이 되면 모형이 일반화(generalize)에 실패하여 train set에 대해서는 과대 적합되고 validation set에는 오히려 정확도가 떨어지게 된다.
#
# 시각화 결과를 살펴보면 훈련 시작시 validation loss가 감소하기 시작하고 몇 epoch 이후에는 평준화되고 이후 증가하기 시작한다는 것을 알 수 있다.
#
# 이때 overfitting이 발생하기 전에 훈련을 조기 종료하는 방법이 Early Stopping이다.
#
# **early-stopping**을 하기 위해서 `tf.keras`에서는 **callback**을 사용한다. `.fit()` method 에서 `callbacks` keyword argument를 사용한다.
#
# ```python
# tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
# ```
#
# * `monitor` argument : training을 종료하기 위해서 모니터링할 성능 지표를 지정한다.
# * `patience` argument : 정해진 epoch 수 모니터링 지표가 상당한 개선이 이루어지지 않으면 훈련을 중단한다.
# * `min_delta` argument :  개선된 것으로 판단할 수 있는 최소값을 지정한다.
#
# 참고) [EarlyStopping
# documentation](https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/keras/callbacks/EarlyStopping#class_earlystopping).

# %%
model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28,1)),
        tf.keras.layers.Dense(512, activation = 'relu'),
        tf.keras.layers.Dense(256, activation = 'relu'),
        tf.keras.layers.Dense(128, activation = 'relu'),
        tf.keras.layers.Dense(64, activation = 'relu'),
        tf.keras.layers.Dense(10, activation = 'softmax')
])


model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Stop training when there is no improvement in the validation loss for 5 consecutive epochs
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

history = model.fit(training_batches,
                    epochs = 100,
                    validation_data=validation_batches,
                    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.9196 - accuracy: 0.6474 - val_loss: 0.7415 - val_accuracy: 0.7087
# Epoch 2/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.6419 - accuracy: 0.7628 - val_loss: 0.5871 - val_accuracy: 0.7839
# Epoch 3/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.5313 - accuracy: 0.8054 - val_loss: 0.5026 - val_accuracy: 0.8171
# Epoch 4/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4680 - accuracy: 0.8284 - val_loss: 0.4490 - val_accuracy: 0.8363
# Epoch 5/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4265 - accuracy: 0.8452 - val_loss: 0.4307 - val_accuracy: 0.8413
# Epoch 6/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.4024 - accuracy: 0.8531 - val_loss: 0.4325 - val_accuracy: 0.8421
# Epoch 7/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3832 - accuracy: 0.8595 - val_loss: 0.4169 - val_accuracy: 0.8473
# Epoch 8/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3673 - accuracy: 0.8646 - val_loss: 0.4037 - val_accuracy: 0.8532
# Epoch 9/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3564 - accuracy: 0.8676 - val_loss: 0.3630 - val_accuracy: 0.8688
# Epoch 10/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3399 - accuracy: 0.8742 - val_loss: 0.3781 - val_accuracy: 0.8654
# Epoch 11/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3336 - accuracy: 0.8767 - val_loss: 0.3757 - val_accuracy: 0.8619
# Epoch 12/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3218 - accuracy: 0.8808 - val_loss: 0.3581 - val_accuracy: 0.8698
# Epoch 13/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3095 - accuracy: 0.8846 - val_loss: 0.3426 - val_accuracy: 0.8753
# Epoch 14/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.3056 - accuracy: 0.8861 - val_loss: 0.3374 - val_accuracy: 0.8812
# Epoch 15/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2964 - accuracy: 0.8893 - val_loss: 0.3456 - val_accuracy: 0.8779
# Epoch 16/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2922 - accuracy: 0.8912 - val_loss: 0.3690 - val_accuracy: 0.8690
# Epoch 17/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2869 - accuracy: 0.8934 - val_loss: 0.3333 - val_accuracy: 0.8796
# Epoch 18/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2755 - accuracy: 0.8991 - val_loss: 0.3801 - val_accuracy: 0.8657
# Epoch 19/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2706 - accuracy: 0.8987 - val_loss: 0.3363 - val_accuracy: 0.8766
# Epoch 20/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2652 - accuracy: 0.9012 - val_loss: 0.3240 - val_accuracy: 0.8825
# Epoch 21/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2617 - accuracy: 0.9032 - val_loss: 0.3252 - val_accuracy: 0.8875
# Epoch 22/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2547 - accuracy: 0.9040 - val_loss: 0.3187 - val_accuracy: 0.8884
# Epoch 23/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2507 - accuracy: 0.9056 - val_loss: 0.3254 - val_accuracy: 0.8850
# Epoch 24/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2445 - accuracy: 0.9078 - val_loss: 0.3318 - val_accuracy: 0.8834
# Epoch 25/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2385 - accuracy: 0.9111 - val_loss: 0.3263 - val_accuracy: 0.8860
# Epoch 26/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2325 - accuracy: 0.9136 - val_loss: 0.3131 - val_accuracy: 0.8886
# Epoch 27/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2295 - accuracy: 0.9135 - val_loss: 0.3595 - val_accuracy: 0.8751
# Epoch 28/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2253 - accuracy: 0.9150 - val_loss: 0.3298 - val_accuracy: 0.8871
# Epoch 29/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2213 - accuracy: 0.9152 - val_loss: 0.3296 - val_accuracy: 0.8859
# Epoch 30/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2131 - accuracy: 0.9205 - val_loss: 0.3317 - val_accuracy: 0.8879
# Epoch 31/100
# 704/704 [==============================] - 2s 3ms/step - loss: 0.2124 - accuracy: 0.9197 - val_loss: 0.3609 - val_accuracy: 0.8792

# %%
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

training_loss = history.history['loss']
validation_loss = history.history['val_loss']

epochs_range=range(len(training_accuracy))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, training_accuracy, label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, training_loss, label='Training Loss')
plt.plot(epochs_range, validation_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Dropout
#
# overfitting 을 해결할 수 있는 또다른 방법으로는  **dropout**이 있다. dropout 은 모형의 훈련과정에서 random하게 network의 일부 neurons을 삭제하는 것이다.  `tf.keras`에서는 `tf.keras.layers.Dropout()` layers 를 활용한다.
#
# ```python
# tf.keras.layers.Dropout(rate)
# ```
#
# * rate : 훈련 중 임의로 삭제할 neuron의 비율을 지정한다. (0~1사이의 값)
#
# input layer에 대해서는 dropout을 지정하지 않는다. 또한 훈련과정에서만 dropout 이 적용되고 훈련이 끝난 모형을 prediction에 사용할때는 dropout이 적용되지 않는다.

# %% [markdown]
# > **Exercise:** 이전에 생성한 모형에 3개의 dropout layers를 추가한다. 이때 `rate=0.2`로 지정하시오. 그리고 해당 모형을 다시 훈련시키고 overfitting 이 해결되는지 확인해 보시오.

# %%
## Solution
my_model = tf.keras.Sequential([
           tf.keras.layers.Flatten(input_shape=(28,28,1)),
           tf.keras.layers.Dense(256, activation = 'relu'),
           tf.keras.layers.Dropout(0.2),
           tf.keras.layers.Dense(128, activation = 'relu'),
           tf.keras.layers.Dropout(0.2),
           tf.keras.layers.Dense(64, activation = 'relu'),
           tf.keras.layers.Dropout(0.2),
           tf.keras.layers.Dense(10, activation = 'softmax')
])

my_model.compile(optimizer='adam',
                 loss='sparse_categorical_crossentropy',
                 metrics=['accuracy'])

EPOCHS = 30

history = my_model.fit(training_batches,
                       epochs=EPOCHS,
                       validation_data=validation_batches)
# Out:
# Epoch 1/30
# 704/704 [==============================] - 1s 2ms/step - loss: 1.0511 - accuracy: 0.5950 - val_loss: 0.6192 - val_accuracy: 0.7647
# Epoch 2/30
# 704/704 [==============================] - 2s 2ms/step - loss: 0.6410 - accuracy: 0.7634 - val_loss: 0.5346 - val_accuracy: 0.8043
# Epoch 3/30
# 704/704 [==============================] - 2s 2ms/step - loss: 0.5619 - accuracy: 0.7987 - val_loss: 0.4894 - val_accuracy: 0.8187
# Epoch 4/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.5126 - accuracy: 0.8169 - val_loss: 0.4748 - val_accuracy: 0.8245
# Epoch 5/30
# 704/704 [==============================] - 2s 2ms/step - loss: 0.4822 - accuracy: 0.8276 - val_loss: 0.4338 - val_accuracy: 0.8390
# Epoch 6/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4567 - accuracy: 0.8359 - val_loss: 0.4085 - val_accuracy: 0.8497
# Epoch 7/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4337 - accuracy: 0.8456 - val_loss: 0.4031 - val_accuracy: 0.8519
# Epoch 8/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4161 - accuracy: 0.8516 - val_loss: 0.3918 - val_accuracy: 0.8554
# Epoch 9/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.4040 - accuracy: 0.8572 - val_loss: 0.3878 - val_accuracy: 0.8593
# Epoch 10/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3926 - accuracy: 0.8604 - val_loss: 0.3880 - val_accuracy: 0.8591
# Epoch 11/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3834 - accuracy: 0.8632 - val_loss: 0.3725 - val_accuracy: 0.8639
# Epoch 12/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3748 - accuracy: 0.8664 - val_loss: 0.3603 - val_accuracy: 0.8696
# Epoch 13/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3645 - accuracy: 0.8707 - val_loss: 0.3593 - val_accuracy: 0.8705
# Epoch 14/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3583 - accuracy: 0.8726 - val_loss: 0.3650 - val_accuracy: 0.8666
# Epoch 15/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3545 - accuracy: 0.8738 - val_loss: 0.3471 - val_accuracy: 0.8737
# Epoch 16/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3478 - accuracy: 0.8757 - val_loss: 0.3529 - val_accuracy: 0.8725
# Epoch 17/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3369 - accuracy: 0.8794 - val_loss: 0.3469 - val_accuracy: 0.8755
# Epoch 18/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3361 - accuracy: 0.8790 - val_loss: 0.3388 - val_accuracy: 0.8785
# Epoch 19/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3326 - accuracy: 0.8806 - val_loss: 0.3323 - val_accuracy: 0.8812
# Epoch 20/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3278 - accuracy: 0.8829 - val_loss: 0.3337 - val_accuracy: 0.8805
# Epoch 21/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3227 - accuracy: 0.8859 - val_loss: 0.3354 - val_accuracy: 0.8797
# Epoch 22/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3160 - accuracy: 0.8867 - val_loss: 0.3351 - val_accuracy: 0.8795
# Epoch 23/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3118 - accuracy: 0.8883 - val_loss: 0.3329 - val_accuracy: 0.8815
# Epoch 24/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3114 - accuracy: 0.8875 - val_loss: 0.3281 - val_accuracy: 0.8831
# Epoch 25/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3047 - accuracy: 0.8911 - val_loss: 0.3240 - val_accuracy: 0.8835
# Epoch 26/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.3007 - accuracy: 0.8916 - val_loss: 0.3273 - val_accuracy: 0.8813
# Epoch 27/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.2964 - accuracy: 0.8924 - val_loss: 0.3238 - val_accuracy: 0.8837
# Epoch 28/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.2913 - accuracy: 0.8942 - val_loss: 0.3221 - val_accuracy: 0.8857
# Epoch 29/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.2895 - accuracy: 0.8953 - val_loss: 0.3191 - val_accuracy: 0.8840
# Epoch 30/30
# 704/704 [==============================] - 1s 2ms/step - loss: 0.2901 - accuracy: 0.8968 - val_loss: 0.3168 - val_accuracy: 0.8875

# %% [markdown]
# ## Inference
#
# 훈련된 모형을 사용하여 prediction을 수행하고 해당 결과를 시각화 하며 표현해 본다.

# %%
for image_batch, label_batch in testing_batches.take(1):
    ps = model.predict(image_batch)
    images = image_batch.numpy().squeeze()
    labels = label_batch.numpy()


plt.figure(figsize=(10,15))

for n in range(30):
    plt.subplot(6,5,n+1)
    plt.imshow(images[n], cmap = plt.cm.binary)
    color = 'green' if np.argmax(ps[n]) == labels[n] else 'red'
    plt.title(class_names[np.argmax(ps[n])], color=color)
    plt.axis('off')
